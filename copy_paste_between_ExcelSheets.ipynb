# %%
#library used: openpyxl, xlrd, time, cProfile
import openpyxl
import xlrd
import time
import xlwt
import cProfile
import re

t0 = time.time()

#load workbooks needed
lian_sourcefile = xlrd.open_workbook(r"C:\Users\Claudia.Ma\Desktop\Task\1. Daily Report\1209\China Omnichannel Commercial Pulsemeter_Tmall_V3.xlsx")
lian_global = lian_sourcefile.sheet_by_name("Tmall Global")
pulsemeter_terminal = openpyxl.load_workbook(r"C:\Users\Claudia.Ma\Desktop\Task\1. Daily Report\1209\China Omnichannel Commercial Pulsemeter_1209.xlsx", data_only = True)
pulsemeter_global = pulsemeter_terminal.get_sheet_by_name("Tmall Global")


#copy range
def copyRange(startCol, startRow, endCol, endRow, sheet):
    rangeSelected = []
    #Loops through selected Rows
    for i in range(startRow,endRow + 1,1):
    #Appends the row to a RowSelected list
        rowSelected = []
        for j in range(startCol,endCol+1,1):
            rowSelected.append(sheet.cell_value(i, j))
    #Adds the RowSelected List and nests inside the rangeSelected
        rangeSelected.append(rowSelected)
 
    return rangeSelected

#paste range
def pasteRange(startCol, startRow, endCol, endRow, sheetReceiving,copiedData):
    countRow = 0
    for i in range(startRow,endRow+1,1):
        countCol = 0
        for j in range(startCol,endCol+1,1):
            sheetReceiving.cell(row = i, column = j).value = copiedData[countRow][countCol]
            countCol += 1
        countRow += 1


#in total
def createData():
    print("Processing...")
    selectedRange = copyRange(5,711,11,711,lian_global) #Change the 4 number values
    pastingRange = pasteRange(5,711,11,711,pulsemeter_global,selectedRange) #Change the 4 number values
    #You can save the template as another file to create a new file here too.s
    pulsemeter_terminal.save(r"C:\Users\Claudia.Ma\Desktop\Task\1. Daily Report\1209\China Omnichannel Commercial Pulsemeter_1209.xlsx")
    print("Range copied and pasted!")

go = createData()

t1 = time.time()
print("TIME USED:",str(t1-t0))
cProfile.run('re.compile("foo|bar")')
# Out:
# C:\Users\Claudia.Ma\AppData\Local\Temp/ipykernel_2892/285143828.py:15: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   pulsemeter_global = pulsemeter_terminal.get_sheet_by_name("Tmall Global")
# Processing...
# Range copied and pasted!
# TIME USED: 54.10946846008301
#          214 function calls (207 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 enum.py:358(__call__)
#         2    0.000    0.000    0.000    0.000 enum.py:670(__new__)
#         1    0.000    0.000    0.000    0.000 enum.py:977(__and__)
#         1    0.000    0.000    0.000    0.000 re.py:250(compile)
#         1    0.000    0.000    0.000    0.000 re.py:289(_compile)
#         1    0.000    0.000    0.000    0.000 sre_compile.py:249(_compile_charset)
# ...
